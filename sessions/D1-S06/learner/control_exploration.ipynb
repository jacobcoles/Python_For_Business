# %% [markdown]
# # D1-S06: Explore before you edit
# Open the course folder in VS Code before running. This notebook reads inputs only; your two functions live in `control_stubs.py`. See slides 5–7 and participant guide sections 3–5.

# %%
# Setup: work from the course folder, whichever folder the notebook kernel started in
import os
from pathlib import Path
here = Path.cwd().resolve()
course_root = next((p for p in [here, *here.parents] if (p / "case_pack").is_dir() and (p / "sessions").is_dir()), None)
if course_root is None:
    raise FileNotFoundError("Open the course folder (the one containing case_pack and sessions) in VS Code.")
os.chdir(course_root)
print("Working directory:", course_root)

# %%
from pathlib import Path
import pandas as pd
rows = pd.read_csv('case_pack/data/clean/tiny/transactions_2025-12_N01.csv', dtype=str)
rows['source_file'] = 'transactions_2025-12_N01.csv'
rows['source_row'] = range(1, len(rows)+1)
print(rows.to_string(index=False))

# %% [markdown]
# **Predict (slides 5–6):** which rows should a duplicate check return for this data, and what should +0.01, +0.02, −0.01 and −0.02 differences do against a control total? Decide what you expect, edit `control_stubs.py`, save it, then run the self-test below to see whether you were right. Rerun it after every edit.

# %%
# Self-test: runs your saved functions from control_stubs.py
# %run sessions/D1-S06/learner/control_stubs.py
